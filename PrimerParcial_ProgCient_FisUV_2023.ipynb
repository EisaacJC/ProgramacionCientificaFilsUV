# %% [markdown]
# <a href="https://colab.research.google.com/github/EisaacJC/ProgramacionCientificaFisUV/blob/main/PrimerParcial_ProgCient_FisUV_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Programacion Cientifica FFis-UV 2023 Primer parcial

# Titulo = 'Titulo del reporte' #@param {type:"string"}
Nombre = 'Nombre completo' #@param {type:"string"}
Matricula = 'Matricula' #@param {type:"string"}
Fecha = '2024-04-11' #@param {type:"date"}
# print(Titulo)
import random
random.seed(Nombre)
print(random.randint(1,31))
print(Nombre)
print(Matricula)
print(Fecha)
# Out:
# 6
# Nombre completo
# Matricula
# 2024-04-11

# %% [markdown]
# # Primer Parte
#
# ## Copiar y pegar el siguiente codigo en el trinket proporcionado.
# **EL CODIGO ESTA DELIBERADAMENTE MAL. Si lo ejecutan despues de copiarlo tal y como esta sin revisarlo tendra errores.**
#
# 1. Los errores en el codigo son de al menos dos tipos:
#  - errores de sintaxis en los que algunas variables estan equivocadas en su definicion
#  - errores de sintaxis en los que faltan simbolos y las construcciones programaticas son incorrectas
#  - errores de tipo numerico que ocasionan que el sistema simulado no se despliegue correctamente.
#
# 2. Determinar los errores, solucionarlo(s) y ejecutar correctamente el codigo.
#
# 3. Una vez ejecutado correctamente, responder las preguntas que siguen:
#
# El resultado debe verse como en la siguiente Figura:
#
# ![Screenshot from 2023-04-11 18-09-51.png](data:image/png;base64,...)
#
#
# ```python
# Web VPython 3.2
#
# g1 = graph(height=200)
# f1=gcurve(color=color.blue, label='y') #markers=True, marker_color=color.orange)
#
# # g2 = graph(height=200)
# # kin=gcurve(color=color.orange, label='kin') #markers=True, marker_color=color.orange)
# # pot=gcurve(color=color.black, label='pot') #markers=True, marker_color=color.orange)
# # tot=gcurve(color=color.red, label='tot') #markers=True, marker_color=color.orange)
#
# ## constants
# g = 9.8         # acceleration due to gravity
# time = 0           # start counting time at zero
# dt = .01   # time step
#
# # starting angle, string length, mass, momentum for object 1
#
# theta = 45
#
# theta1 = theta*pi 180 # starting angle in rads
# L1 = 0.8     # string length
# m1 = 0.1  # ball mass in kg
# v1 = vector(0,0,0)  # initial velocity of pendulum (x,y,z) directions
# p1 = m1*v1 # starting momentum
#
#
# # treat the strings as springs with very large k to get tension
# k = 1e5
#
# ## create the ceiling, masses, and strings
# ceiling = box(pos=vector(-0.5,1,0), size = vector(0.2, 0.01, 0.2))
# ball1 = sphere(pos=vector(ceiling.pos.x-L1*sin(theta1),ceiling.pos.y-L1*cos(theta1),0), radius=0.05, color=color.green , make_trail=True,interval=40,retain=1e4)
# ball1.trail_object.color=color.cyan
# # ball1.trail_object.radius=0.005
# string1 = cylinder(pos=ceiling.pos, axis=ball1.pos-ceiling.pos, color=color.white, radius=0.008)
#
#
# # def kegy():
# #     """calcula the kinetic energy de ball1"""
# #     return 0.5*p1.dot(p1)/
#
# # def pegy():
# #     """calcula potential energy de ball1"""
# #     return  *(-ceiling.pos.y + ball1.pos.y)*g
#
#
# ## calculation loop
# while time < 10:
#     rate(1/dt)
#
#     # calc radial vectors and forces
#     r1 = vector(ball1.pos.x - ceiling.pos.x,ball1.pos.y - ceiling.pos.y,ball1.pos.z - ceiling.pos.z)
#     F1 = m1*vector(0,-g,0) - k*(r1 - L1*r1.norm())
#
#     p1 = p1 + F1 dt #change in momentum of pendulum
#     ball1.pos = ball1.pos + (p1/m1)*dt  #change in position of pendulum
#     string1.axis = ball1.pos - ceiling.pos #rotates string
#     f1.plot(time, ball1.pos.y) #graphs horizontal and vertical position v. time of pendulum
#     # ek =
#     # =pegy()
#     # et = ek  ep
#     # kin.plot(time, ek)
#     # pot.plot(time, ep)
#     # tot.plot(time, et)
#     scene.caption = "Time =" + time
# time = time + dt
#
# ```

# %%
#@title Visual Python Primera Parte
# %%html

<iframe src="https://trinket.io/embed/glowscript/5bb30d8841?toggleCode=true" width="100%" height="600" frameborder="0" marginwidth="0" marginheight="0" allowfullscreen></iframe>

# %%
#@title Responder con base en los resultados del codigo ejecutado
#@markdown Forms support many types of fields.

#@markdown Cual es la velocidad inicial de la masa en el pendulo? Recuerde que la velocidad es un vector.
v0 = ''  #@param
#@markdown Cual es altura inicial (con respecto al sistema de coordenadas elegido en la simulacion)?
h0 = ''  #@param 
#@markdown Cual es el angulo incial con respecto a la horizontal?
theta0 = ''  #@param 
#@markdown Cual es la velocidad maxima alcanzada por la masa durante su movimiento?
vmax = ''  #@param 
#@markdown Puede estimar el periodo del pendulo?
vmax = ''  #@param 
#@markdown ---

# %% [markdown]
# # Segunda Parte
#
# Utilizando el codigo funcional de la Primera Parte, modificar el resto de modo que se visualize la energia cinetica, potencial y la suma de ambas.
#
#  El resultado visual debe ser similar a la siguiente figura:
#
#  ![Screenshot from 2023-04-11 21-14-15.png](data:image/png;base64,...)

# %%
#@title Responder con base en los resultados del codigo ejecutado
#@markdown Forms support many types of fields.

#@markdown Cual es el valor inicial de la energia cinetica?
ke0 = ''  #@param
#@markdown Cual es el valor inicial de la energia potencial?
pe0 = ''  #@param 
#@markdown Se observa la conservacion de la energia total del sistema para las condiciones inciales usadas?
res = 'No/Si. Indicar y explicar porque'  #@param {type: "string"}
#@markdown Se cumple la conservacion de energia para diferentes valores de theta inicial? 
res1 = 'No/Si. Indicar y explicar porque'  #@param {type: "string"}
#@markdown Indicar que valores del angulo se usaron para responder esta pregunta. Mostrar evidencia para valores del angulo usados.
vmax = ''  #@param 
#@markdown ---

# %%
#@title Visual Python Segunda Parte
# %%html

<iframe src="https://trinket.io/embed/glowscript/5bb30d8841?toggleCode=true" width="100%" height="600" frameborder="0" marginwidth="0" marginheight="0" allowfullscreen></iframe>
